# %% [markdown]
# # Python_Basics_Assignment 12

# %% [markdown]
# 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# File object passed to PyPDF2.PdfFileReader() needs to be opened in read-binary mode by passing 'rb' as the second argument to open(). Likewise, the File object passed to PyPDF2.PdfFileWriter() needs to be opened in write-binary mode with 'wb'.

# %% [markdown]
# 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %% [markdown]
# We can get a Page object by calling the getPage() method on a PdfFileReader object and passing it the page number of the page we’re interested in.
#
# PyPDF2 uses a zero-based index for getting pages: The first page is page 0, the second is page 1, and so on. This is always the case, even if pages are numbered differently within the document. For example, say your PDF is a three-page excerpt from a longer report, and its pages are numbered 42, 43, and 44. To get the first page of this document, you would want to call pdfReader.getPage(0), not getPage(42) or getPage(1).

# %% [markdown]
# 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %% [markdown]
# The total number of pages in the document is stored in the numPages attribute of a PdfFileReader object.

# %% [markdown]
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %% [markdown]
# Before we obtain the page object, the pdf has to be decrypted by calling .decrypt('swordfish')

# %% [markdown]
# 5. What methods do you use to rotate a page?

# %% [markdown]
# The pages of a PDF can be rotated in 90-degree increments with the rotateClockwise() and rotateCounterClockwise() methods. Pass one of the integers 90, 180, or 270 to these methods.

# %% [markdown]
# 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Paragraph object:- The Document object contains a list of Paragraph objects for the paragraphs in the document. (A new paragraph begins whenever the user presses ENTER or RETURN while typing in a Word document.) Each of these Paragraph objects contains a list of one or more Run objects.
#
# ![image.png](attachment:image-2.png)
#
# fig.: The run objects identified in a paragraph object
#
# Run object:- The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it. A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %% [markdown]
# doc.paragraphs attribute will give a list of paragraphs in the document object doc.

# %%
# import docx
# doc = docx.Document('test.docx')
# doc.paragraphs

# %% [markdown]
# 8. What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# the Run object has bold, underline, italic, strike and outline variables.

# %% [markdown]
# 9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# Runs can be styled using text attributes. Each attribute can be set to one of three values:
# - True (the attribute is always enabled, no matter what other styles are applied to the run),
# - False (the attribute is always disabled), or
# - None (defaults to whatever the run’s style is set to).
#
# So for bold variable:
# * bold = True  # Style Set to Bold
# * bold = False # Style Not Set to Bold
# * bold = None # Style is Not Applicable

# %% [markdown]
# 10. How do you create a Document object for a new Word document?

# %% [markdown]
# To create a .docx file, call docx.Document() to return a new, blank Word Document object.

# %%
# import docx
# doc = docx.Document()
# doc.add_paragraph('Hello, world!')
# doc.save('helloworld.docx')

# %% [markdown]
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %%
import docx
doc = docx.Document()
doc.add_paragraph('Hello, there!')
doc.save('hello.docx')

# %% [markdown]
# 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4. The integer 0 makes the heading the Title style, which is used for the top of the document. Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading with decreasing font sizes.

# %%
# doc = docx.Document()
# doc.add_heading('Header 0', 0)
# doc.add_heading('Header 1', 1)
# doc.add_heading('Header 2', 2)
# doc.add_heading('Header 3', 3)
# doc.add_heading('Header 4', 4)
# doc.save('headings.docx')
